# %% [markdown]
# # Embeddings and Vector Database (Azure AI Search)
#
# ## Part 1: Create the index with the Import Data wizard
#
# This notebook is a documentation-first template for the first part of the assignment. It follows the same practical style used in the previous notebooks: clear setup, guided steps, evidence placeholders, and short conclusions.
#
# Use this notebook as a live report while you work in the Azure portal. Add your screenshots, copy the values you choose, and complete the short reflections after each step.

# %% [markdown]
# ## Objective
#
# Build and document an Azure AI Search indexing pipeline using the portal's **Import data** wizard with integrated vectorization.
#
# The goal of this first part is to create the index, understand how the wizard configures the search resources, and capture the evidence needed for the assignment: index schema, semantic configuration, vector profile, and skillset.

# %% [markdown]
# ## 0) How to use this notebook
#
# 1. Read the assignment instructions before starting in the portal.
# 2. Follow the portal steps in order and capture screenshots after each important decision.
# 3. Paste the screenshots into the `images/` folder of this assignment if you want to keep them organized.
# 4. Replace each placeholder below with your actual screenshot and a short explanation.
# 5. Keep your notes short but specific: what you selected, why you selected it, and what the wizard created.

# %% [markdown]
# ## 1) Assignment scope
#
# This practice has two parts. This notebook covers **Part 1 only**: the documentation of the wizard-based index creation flow.
#
# What you must document here:
# - The index schema generated by the wizard.
# - The semantic configuration.
# - The vector profile, including algorithm and vectorizer settings.
# - The skillset created by the wizard if enrichment is enabled.

# %% [markdown]
# ## 2) Prerequisites checklist
#
# Before opening the wizard, confirm the following items are ready:
#
# - An Azure subscription with permission to create or use an Azure AI Search resource.
# - An Azure AI Search service with Basic tier or higher recommended.
# - An Azure Blob Storage container that contains the documents to index.
# - An Azure OpenAI or Foundry embeddings deployment available for vectorization.
# - Access to the portal where you can use **Import data**.
# - A place to store screenshots so you can paste them into this notebook later.
#
# If any of these are missing, stop and fix the prerequisite first. The wizard depends on all of them being available.

# %% [markdown]
# ## 3) Step-by-step portal workflow
#
# Follow this sequence carefully. The wizard creates several resources behind the scenes, and it is easier to explain the result if you document the flow in the same order that Azure shows it.
#
# ### 3.1 Open Azure AI Search
# 1. Go to your Azure AI Search resource in the Azure portal.
# 2. Verify that the resource is the one you want to use for the assignment.
# 3. Open the **Import data** wizard.
#
# ### 3.2 Choose the scenario
# 1. Select the **RAG** scenario.
#
# ### 3.3 Connect the data source
# 1. Choose **Azure Blob Storage** as the source.
# 2. Select the storage account and container that contains the documents.
# 3. Use the required authentication method, such as managed identity or key.
# 4. Confirm that the file types in the container match the documents you intend to index.
#
# ### 3.4 Configure vectorization
# 1. Enable vectorization in the wizard.
# 2. Select the embeddings provider and the embeddings deployment.
# 3. Note the model name, deployment name, and any dimension settings shown by the portal.
#
# ### 3.5 Review the inferred schema
# 1. Let the wizard infer the fields from the documents.
# 2. Check the fields that become searchable, retrievable, filterable, sortable, or facetable.
# 3. Confirm the key field and vector field are created correctly.
# 4. If the schema needs changes, record what you changed and why.
#
# ### 3.6 Review semantic configuration
# 1. Open the semantic configuration section.
# 2. Identify the title field, content fields, and keyword fields.
#
# ### 3.7 Review vector profile settings
# 1. Open the vector profile section.
# 2. Capture the algorithm configuration.
# 3. Capture the vectorizer configuration.
#
# ### 3.8 Review the skillset
# 1. If enrichment is enabled, inspect the skillset generated by the wizard.
# 2. Note the skills included, such as text splitting, OCR, or embedding-related steps if they appear.

# %% [markdown]
# ## 4) Evidence
#
#  > All screenshots and exported JSON below correspond to the index created with the Import data wizard.
#
# ### 4.1 Index schema
# **Evidence type:** JSON export from the created index.
#
# ```json
# {
#   "@odata.etag": "\"0x8DE9B24376F8376\"",
#   "name": "rag-1776279755924",
#   "purviewEnabled": false,
#   "fields": [
#     {
#       "name": "chunk_id",
#       "type": "Edm.String",
#       "searchable": true,
#       "filterable": false,
#       "retrievable": true,
#       "stored": true,
#       "sortable": true,
#       "facetable": false,
#       "key": true,
#       "analyzer": "keyword",
#       "synonymMaps": []
#     },
#     {
#       "name": "parent_id",
#       "type": "Edm.String",
#       "searchable": false,
#       "filterable": true,
#       "retrievable": true,
#       "stored": true,
#       "sortable": false,
#       "facetable": false,
#       "key": false,
#       "synonymMaps": []
#     },
#     {
#       "name": "chunk",
#       "type": "Edm.String",
#       "searchable": true,
#       "filterable": false,
#       "retrievable": true,
#       "stored": true,
#       "sortable": false,
#       "facetable": false,
#       "key": false,
#       "synonymMaps": []
#     },
#     {
#       "name": "title",
#       "type": "Edm.String",
#       "searchable": true,
#       "filterable": false,
#       "retrievable": true,
#       "stored": true,
#       "sortable": false,
#       "facetable": false,
#       "key": false,
#       "synonymMaps": []
#     },
#     {
#       "name": "text_vector",
#       "type": "Collection(Edm.Single)",
#       "searchable": true,
#       "filterable": false,
#       "retrievable": true,
#       "stored": true,
#       "sortable": false,
#       "facetable": false,
#       "key": false,
#       "dimensions": 1536,
#       "vectorSearchProfile": "rag-1776279755924-aiFoundryCatalog-text-profile",
#       "synonymMaps": []
#     }
#   ],
#   "scoringProfiles": [],
#   "suggesters": [],
#   "analyzers": [],
#   "normalizers": [],
#   "tokenizers": [],
#   "tokenFilters": [],
#   "charFilters": [],
#   "similarity": {
#     "@odata.type": "#Microsoft.Azure.Search.BM25Similarity"
#   },
#   "vectorSearch": {
#     "algorithms": [
#       {
#         "name": "rag-1776279755924-algorithm",
#         "kind": "hnsw",
#         "hnswParameters": {
#           "metric": "cosine",
#           "m": 4,
#           "efConstruction": 400,
#           "efSearch": 500
#         }
#       }
#     ],
#     "profiles": [
#       {
#         "name": "rag-1776279755924-aiFoundryCatalog-text-profile",
#         "algorithm": "rag-1776279755924-algorithm",
#         "vectorizer": "rag-1776279755924-aiFoundryCatalog-text-vectorizer"
#       }
#     ],
#     "vectorizers": [
#       {
#         "name": "rag-1776279755924-aiFoundryCatalog-text-vectorizer",
#         "kind": "azureOpenAI",
#         "azureOpenAIParameters": {
#           "resourceUri": "https://04-embeddings-vector-da-resource.openai.azure.com",
#           "deploymentId": "text-embedding-ada-002",
#           "apiKey": "<redacted>",
#           "modelName": "text-embedding-ada-002"
#         }
#       }
#     ],
#     "compressions": []
#   }
# }
# ```
#
# Explanation:
# - `chunk_id` is the key field, which uniquely identifies each indexed chunk and prevents collisions.
# - `chunk` and `title` are the main retrieval text fields, providing readable context in results.
# - `text_vector` stores 1536-dimensional embeddings that power vector similarity search.
# - `parent_id` is filterable and groups chunks by source document for traceability and filtering.
#
# ### 4.2 Semantic configuration
# ![Semantic configuration](images/01_semantic_configuration.png)
#
# Explanation:
# - Semantic configuration name is `default-configuration`, which semantic ranking applies at query time.
# - `title` is mapped as the Title field, helping prioritize topic-level relevance.
# - `chunk` is mapped as the Content field, giving the semantic ranker the main contextual signal.
# - Keyword field is empty in this setup, which is acceptable because no dedicated metadata keyword field exists.
#
# ### 4.3 Semantic search validation (next to semantic configuration)
# #### 4.3.1 Baseline simple query
# ![Simple query result](images/02_simple_query_baseline.png)
#
# Explanation:
# - This is the baseline lexical ranking result, serving as the control case before semantic ranking.
# - It helps compare whether semantic ranking adds measurable relevance improvements.
#
# #### 4.3.2 Query options before semantic query
# ![Semantic query options](images/03_query_options_semantic_enabled.png)
#
# Explanation:
# - Semantic ranker is enabled in Query options to activate semantic scoring logic.
# - `default-configuration` is selected to tell the engine which semantic field mapping to apply.
# - This step is required so the next query runs in semantic mode and not simple mode.
#
# #### 4.3.3 Semantic query result
# ![Semantic query result](images/04_semantic_query_result.png)
#
# Explanation:
# - The same question is executed with semantic ranking enabled for direct comparison against the baseline.
# - Semantic response includes answer-oriented metadata and improved context matching.
# - This evidence confirms semantic configuration is correctly applied and useful for relevance quality.
#
# ### 4.4 Vector profile (Algorithm + Vectorizer)
# #### 4.4.1 Algorithm configuration
# ![Vector algorithm configuration](images/05_vector_algorithm_configuration.png)
#
# Explanation:
# - HNSW with cosine similarity is the vector nearest-neighbor algorithm that enables efficient similarity retrieval.
# - Parameters (`m=4`, `efConstruction=400`, `efSearch=500`) control index graph quality and search recall.
# - This configuration balances speed, memory use, and retrieval quality for this dataset size.
#
# #### 4.4.2 Vectorizer configuration
# ![Vectorizer configuration](images/06_vectorizer_configuration.png)
#
# Explanation:
# - Vectorizer is connected to Microsoft Foundry and generates embeddings from text.
# - Model deployment is `text-embedding-ada-002`, configured as the embedding model for indexing and querying.
# - Using the same deployment at ingestion and query time is required for consistent vector matching.
#
# ### 4.5 Skillset
# **Evidence type:** JSON export of the wizard-generated skillset.
#
# ```json
# {
#   "@odata.etag": "\"0x8DE9B24387BADC0\"",
#   "name": "rag-1776279755924-skillset",
#   "description": "Skillset to chunk documents and generate embeddings",
#   "skills": [
#     {
#       "@odata.type": "#Microsoft.Skills.Text.SplitSkill",
#       "name": "#1",
#       "description": "Split skill to chunk documents",
#       "context": "/document",
#       "defaultLanguageCode": "en",
#       "textSplitMode": "pages",
#       "maximumPageLength": 2000,
#       "pageOverlapLength": 500,
#       "maximumPagesToTake": 0,
#       "unit": "characters",
#       "inputs": [
#         {
#           "name": "text",
#           "source": "/document/content",
#           "inputs": []
#         }
#       ],
#       "outputs": [
#         {
#           "name": "textItems",
#           "targetName": "pages"
#         }
#       ]
#     },
#     {
#       "@odata.type": "#Microsoft.Skills.Text.AzureOpenAIEmbeddingSkill",
#       "name": "#2",
#       "context": "/document/pages/*",
#       "resourceUri": "https://04-embeddings-vector-da-resource.openai.azure.com",
#       "apiKey": "<redacted>",
#       "deploymentId": "text-embedding-ada-002",
#       "dimensions": 1536,
#       "modelName": "text-embedding-ada-002",
#       "inputs": [
#         {
#           "name": "text",
#           "source": "/document/pages/*",
#           "inputs": []
#         }
#       ],
#       "outputs": [
#         {
#           "name": "embedding",
#           "targetName": "text_vector"
#         }
#       ]
#     }
#   ],
#   "indexProjections": {
#     "selectors": [
#       {
#         "targetIndexName": "rag-1776279755924",
#         "parentKeyFieldName": "parent_id",
#         "sourceContext": "/document/pages/*",
#         "mappings": [
#           {
#             "name": "text_vector",
#             "source": "/document/pages/*/text_vector",
#             "inputs": []
#           },
#           {
#             "name": "chunk",
#             "source": "/document/pages/*",
#             "inputs": []
#           },
#           {
#             "name": "title",
#             "source": "/document/title",
#             "inputs": []
#           }
#         ]
#       }
#     ],
#     "parameters": {
#       "projectionMode": "skipIndexingParentDocuments"
#     }
#   }
# }
# ```
#
# Explanation:
# - `SplitSkill` divides long documents into smaller chunks, improving retrieval precision and context focus.
# - `AzureOpenAIEmbeddingSkill` generates vectors for each chunk, enabling semantic similarity search.
# - Index projections map enriched outputs to final index fields, building the searchable chunk-level index.
